# %%
import requests
url = 'http://147.45.108.69:5000/login'
headers = {"login": "abcd", "Password": "lexalox1"}
r = requests.get(url, headers=headers)
print(r.status_code)
print(r.json())
# Out:
# 200
# {'response': 'Success!', 'user_id': 1}
